# %% [markdown]
# <a href="https://colab.research.google.com/github/manammadhan123/Case-Madhan/blob/main/Untitled13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data={
    'age':[19,20,21,22],
    'salary':[20000,22000,25000,45000],
    'city':['mumbai','chennai','goa','ongole'],
    'education':['high school','bachelor','master','phd']
}
df=pd.DataFrame(data)
df
# Out:
#    age  salary     city    education
# 0   19   20000   mumbai  high school
# 1   20   22000  chennai     bachelor
# 2   21   25000      goa       master
# 3   22   45000   ongole          phd

# %%
numerical=df.select_dtypes(include=['int64','float64']).columns
categorical=df.select_dtypes(include=['object']).columns
print(numerical.tolist())
print(categorical.tolist())
# Out:
# ['age', 'salary']
# ['city', 'education']

# %%
df['city']=df['city'].astype('category')
df['education']=df['education'].astype('category')

# %%
nominal=['city']
ordinal=['education']

# %%
order=['high school','bachelor','master','phd']
df['education']=pd.Categorical(df['education'],categories=order,ordered=True)
print(df[['education']])
# Out:
#      education
# 0  high school
# 1     bachelor
# 2       master
# 3          phd

# %%
from sklearn.preprocessing import OrdinalEncoder
encoder=OrdinalEncoder(categories=[order])
df['education_encoded']=encoder.fit_transform(df[['education']])
df
# Out:
#    age  salary     city    education  education_encoded
# 0   19   20000   mumbai  high school                0.0
# 1   20   22000  chennai     bachelor                1.0
# 2   21   25000      goa       master                2.0
# 3   22   45000   ongole          phd                3.0

# %%
from sklearn.preprocessing import LabelEncoder
encoder=LabelEncoder()
df['city_encoded']=encoder.fit_transform(df[['city']])
df
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#    age  salary     city    education  education_encoded  city_encoded
# 0   19   20000   mumbai  high school                0.0             2
# 1   20   22000  chennai     bachelor                1.0             0
# 2   21   25000      goa       master                2.0             1
# 3   22   45000   ongole          phd                3.0             3

# %%
df['city_freq']=df['city'].map(df['city'].value_counts(normalize=True))
df
# Out:
#    age  salary     city    education  education_encoded  city_encoded  \
# 0   19   20000   mumbai  high school                0.0             2
# 1   20   22000  chennai     bachelor                1.0             0
# 2   21   25000      goa       master                2.0             1
# 3   22   45000   ongole          phd                3.0             3
#
#    city_freq
# 0       0.25
# 1       0.25
# 2       0.25
# 3       0.25

# %%
mean=df.groupby('city')['salary'].mean()
df['city_encodedmean']=df['city'].map(mean)
df
# Out:
# <ipython-input-15-802d98479d83>:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   mean=df.groupby('city')['salary'].mean()
#    age  salary     city    education  education_encoded  city_encoded  \
# 0   19   20000   mumbai  high school                0.0             2
# 1   20   22000  chennai     bachelor                1.0             0
# 2   21   25000      goa       master                2.0             1
# 3   22   45000   ongole          phd                3.0             3
#
#    city_freq city_encodedmean
# 0       0.25          20000.0
# 1       0.25          22000.0
# 2       0.25          25000.0
# 3       0.25          45000.0
